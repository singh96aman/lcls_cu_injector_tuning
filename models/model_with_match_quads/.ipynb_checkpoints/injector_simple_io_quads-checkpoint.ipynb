# %%
from injector_surrogate_quads import *

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.23.2'

# %% [markdown]
# <a id="init"></a>
# # Initial Info - SHOULD WORK WITHOUT ANY OF THIS

# %% [markdown]
# ### Loading basic model info
# todo - put into config file

# %%
#load model info
model_info = json.load(open('./model_info.json'))

#inputs and outputs model is  trained on
model_in_list = model_info['model_in_list']
model_out_list = model_info['model_out_list']

#dictionary of location of variables in array
loc_in = model_info['loc_in']
loc_out = model_info['loc_out']

#inputs and outputs model is  trained on
input_mins = model_info['train_input_mins']
input_maxs = model_info['train_input_maxs']

# %% [markdown]
# ### Conversion between sim and machine

# %% [markdown]
# Explanation on model inputs and how they relate to PVs:
# https://github.com/slaclab/lcls-cu-inj-surrogate/blob/master/pv_mapping/cu_inj_impact.csv

# %%
pv_info = json.load(open('./pvinfo.json'))

# %%
pv_info.keys()
# Out:
# dict_keys(['pv_to_sim_factor', 'pv_unit', 'pv_name_to_sim_name', 'sim_name_to_pv_name', 'sim_to_pv_factor'])

# %%
pv_to_sim_factor = pv_info['pv_to_sim_factor']
sim_to_pv_factor = pv_info['sim_to_pv_factor']
pv_unit = pv_info['pv_unit']
pv_name_to_sim_name = pv_info['pv_name_to_sim_name']
sim_name_to_pv_name = pv_info['sim_name_to_pv_name']

# %%
model_in_list
# Out:
# ['distgen:r_dist:sigma_xy:value',
#  'distgen:t_dist:length:value',
#  'distgen:total_charge:value',
#  'SOL1:solenoid_field_scale',
#  'CQ01:b1_gradient',
#  'SQ01:b1_gradient',
#  'L0A_scale:voltage',
#  'L0A_phase:dtheta0_deg',
#  'L0B_scale:voltage',
#  'L0B_phase:dtheta0_deg',
#  'QA01:b1_gradient',
#  'QA02:b1_gradient',
#  'QE01:b1_gradient',
#  'QE02:b1_gradient',
#  'QE03:b1_gradient',
#  'QE04:b1_gradient']

# %%
sim_name_to_pv_name
# Out:
# {'distgen:r_dist:sigma_xy:value': 'IRIS:LR20:130:CONFG_SEL',
#  'SOL1:solenoid_field_scale': 'SOLN:IN20:121:BDES',
#  'CQ01:b1_gradient': 'QUAD:IN20:121:BDES',
#  'SQ01:b1_gradient': 'QUAD:IN20:122:BDES',
#  'L0A_phase:dtheta0_deg': 'ACCL:IN20:300:L0A_PDES',
#  'L0B_phase:dtheta0_deg': 'ACCL:IN20:400:L0B_PDES',
#  'L0A_scale:voltage': 'ACCL:IN20:300:L0A_ADES',
#  'L0B_scale:voltage': 'ACCL:IN20:400:L0B_ADES',
#  'QA01:b1_gradient': 'QUAD:IN20:361:BDES',
#  'QA02:b1_gradient': 'QUAD:IN20:371:BDES',
#  'QE01:b1_gradient': 'QUAD:IN20:425:BDES',
#  'QE02:b1_gradient': 'QUAD:IN20:441:BDES',
#  'QE03:b1_gradient': 'QUAD:IN20:511:BDES',
#  'QE04:b1_gradient': 'QUAD:IN20:525:BDES',
#  'distgen:t_dist:length:value': 'Pulse_length',
#  'distgen:total_charge:value': 'Charge'}

# %% [markdown]
# # Load Model

# %%
Model = Surrogate_NN()

Model.load_saved_model(model_path = './', model_name = 'model_OTR2_NA_rms_emit_elu_2021-07-19T09_46_52-07_00')
Model.load_scaling()

# %% [markdown]
# ### Example: Predict sim units

# %%
#sim units
X_true = np.load('x_raw_small.npy',allow_pickle=True)
Y_true = np.load('y_raw_small.npy',allow_pickle=True)

# %%
Model.take_log_out = False

# %%
# maketake_log_outdictions in sim units
Y_pred = Model.pred_sim_units(X_true)

# %%
 for i in range(0,Y_true.shape[1]):
    idx=np.argsort(Y_true[:,i])
    plt.plot(Y_true[idx,i],'.',alpha=0.5)
    plt.plot(Y_pred[idx,i],'.',alpha=0.5)
    plt.yscale('log')
    plt.title(Model.model_out_list[i])
    plt.ylabel(Model.model_out_list[i])
    plt.xlabel('Sample Number')
    plt.legend(['True','Predicted'])
    plt.show()

# %% [markdown]
# ### Example: Predict machine units

# %%
#Get some machine unit values by converting sim data
X_true_pv = Model.sim_to_machine(np.asarray(X_true))

# %%
Y_pred_pv = Model.pred_machine_units(X_true_pv);

# %%
Y_pred_sim = Model.pred_sim_units(X_true);

# %%
 for i in range(0,Y_true.shape[1]):
    idx=np.argsort(Y_true[:,i])
    plt.plot(Y_true[idx,i],'.',alpha=0.5)
    plt.plot(Y_pred_pv[idx,i],'.',alpha=0.5)
    plt.plot(Y_pred_sim[idx,i],'.',alpha=0.5)
    plt.yscale('log')
    plt.title(Model.model_out_list[i])
    plt.ylabel(Model.model_out_list[i])
    plt.xlabel('Sample Number')
    plt.legend(['True','Predicted-pv-units','Predicted-sim-units'])
    plt.show()

# %% [markdown]
# # SCAN OF Q525

# %%
 scanlist=[
'scan_SOL1:solenoid_field_scale-fine2.json',
'scan_SQ01:b1_gradient-fine2.json',
'scan_CQ01:b1_gradient-fine2.json',]
    
FIGNAME= 'SOL_'
PATHSCAN = '../../../sims/'
dat1 = json.load(open(PATHSCAN+scanlist[0]))

# %%
inputs=pd.DataFrame(dat1['inputs'])
outputs=pd.DataFrame(dat1['outputs'])

# %%
matchq=['QA01:b1_gradient','QA02:b1_gradient','QE01:b1_gradient','QE02:b1_gradient','QE03:b1_gradient','QE04:b1_gradient']
matchqv=['  1.85240001e+00', '-1.85240001e+00','1.87200002e-01',  '1.66100000e-01', '-2.64090000e+00',  '2.97999999e+00']
ref_point = [4.23867825e-01,
                      3.06083484e+00,
                      2.50000000e+02,
                      2.45806452e-01,
                      7.13917676e-04,
                      3.27285211e-04,
                      5.80000000e+07,
                      -9.53597349e+00,
                      7.00000000e+07,
                        9.85566222e+00,
                          1.85240001e+00,
                      -1.85240001e+00,
                        1.87200002e-01,
                        1.66100000e-01,
                      -2.64090000e+00,
                        2.97999999e+00]
numscan=100
x_raw_scan = np.empty((numscan,len(ref_point) ))
                      
                      
for i in range(0,len(ref_point)):
    x_raw_scan[:,i]=ref_point[i] 

scan = np.linspace(0,7,numscan)
x_raw_scan[:,-1]=scan
mine = 5.461418942827289e-07


#x_scan=Model.transformer_x.transform(x_raw_scan)



Y_pred_scalar = Model.pred_sim_units(x_raw_scan)

#Y_pred = Model.transformer_y.inverse_transform(Y_pred_scalar)
#X_scan = Model.transformer_x.inverse_transform(x_scan)
plt.plot(X_scan[:,loc_in['QE04:b1_gradient']],Y_pred_scalar[:,0])
plt.plot(X_scan[:,loc_in['QE04:b1_gradient']],Y_pred_scalar[:,1])
plt.show()

# %% [markdown]
# <a id="BO"></a>
# # Small BO Run

# %%
#ref point from sim
ref_point = [[4.23867825e-01,
                      3.06083484e+00,
                      2.50000000e+02,
                      2.45806452e-01,
                      7.13917676e-04,
                      3.27285211e-04,
                      5.80000000e+07,
                      -9.53597349e+00,
                      7.00000000e+07,
                        9.85566222e+00,
                          1.85240001e+00,
                      -1.85240001e+00,
                        1.87200002e-01,
                        1.66100000e-01,
                      -2.64090000e+00,
                        2.97999999e+00]]




#convert to machine units
ref_point = Model.sim_to_machine(np.asarray(ref_point))

#nested_list
ref_point=[ref_point[0]]


opt_var_names = ['SOL1:solenoid_field_scale','SQ01:b1_gradient','CQ01:b1_gradient']
opt_out_names = ['norm_emit_x','norm_emit_y']

def evaluate(varx,vary,varz):

    #make input array of length model_in_list
    x_in = np.empty((1,len(Model.model_in_list)))

    #fill in reference point around whicch to optimize
    x_in[:,:] = np.asarray(ref_point)

    #set solenoid, SQ, CQ to values from optimization step
    x_in[:, Model.loc_in[opt_var_names[0]]] = varx
    x_in[:, Model.loc_in[opt_var_names[1]]] = vary
    x_in[:, Model.loc_in[opt_var_names[2]]] = varz

    y_out = Model.pred_machine_units(x_in) 
    print(y_out)

    return -1*objective(y_out)[0]


def objective(y_out):
    out1 = y_out[:,Model.loc_out['norm_emit_x']] #grab norm_emit_x out of the model
    out2 = y_out[:,Model.loc_out['norm_emit_y']] #grab norm_emit_y out of the model
    
    return np.sqrt(out1*out2)

# %%
opt_var_names = ['SOL1:solenoid_field_scale','SQ01:b1_gradient','CQ01:b1_gradient']
opt_out_names = ['norm_emit_x','norm_emit_y']

def evaluate(varx,vary,varz):

    #make input array of length model_in_list
    x_in = np.empty((1,len(Model.model_in_list)))

    #fill in reference point around whicch to optimize
    x_in[:,:] = np.asarray(ref_point)

    #set solenoid, SQ, CQ to values from optimization step
    x_in[:, Model.loc_in[opt_var_names[0]]] = varx
    x_in[:, Model.loc_in[opt_var_names[1]]] = vary
    x_in[:, Model.loc_in[opt_var_names[2]]] = varz

    y_out = Model.pred_machine_units(x_in) 
    print(y_out)

    return -1*objective(y_out)[0]


def objective(y_out):
    out1 = y_out[:,Model.loc_out['norm_emit_x']] #grab norm_emit_x out of the model
    out2 = y_out[:,Model.loc_out['norm_emit_y']] #grab norm_emit_y out of the model
    
    return np.sqrt(out1*out2)

# %%
from bayes_opt import BayesianOptimization

pbounds = {'varx': (0.44, 0.55),
           'vary': (-0.02, 0.02),
           'varz': (-0.02, 0.02)}

optimizer = BayesianOptimization(
    f = evaluate,
    pbounds = pbounds,
    random_state = 1,
)

optimizer.maximize(
    init_points=10,
    n_iter=40,
)
# Out:
# |   iter    |  target   |   varx    |   vary    |   varz    |
# [[9.2093971e-05 1.0634029e-04 4.6231496e-04 5.6587231e-07 5.8413400e-07]]
# |  36       | -5.749e-0 |  0.4775   |  0.000240 | -0.000810 |
# [[9.1027076e-05 1.2542542e-04 4.6167092e-04 5.6618507e-07 5.8688414e-07]]
# |  37       | -5.764e-0 |  0.4765   |  0.00244  | -0.000805 |
# [[9.0813388e-05 1.2385477e-04 4.6175532e-04 5.6537158e-07 5.8663090e-07]]
# |  38       | -5.759e-0 |  0.4765   |  0.002055 | -0.001166 |
# [[9.6250929e-05 1.0446778e-04 4.6237506e-04 5.6595701e-07 5.8463962e-07]]
# |  39       | -5.752e-0 |  0.4777   |  0.00148  | -0.000433 |
# [[9.3083538e-05 9.9926976e-05 4.6267765e-04 5.6833255e-07 5.8600665e-07]]
# |  40       | -5.771e-0 |  0.4779   | -0.001058 | -0.000935 |
# [[8.9103109e-05 1.0602986e-04 4.6211955e-04 5.6601328e-07 5.8416771e-07]]
# |  41       | -5.75e-07 |  0.4774   | -0.000498 |  0.000499 |
# [[3.1588326e-04 6.9678167e-04 4.8232236e-04 1.2683902e-06 1.5198545e-06]]
# |  42       | -1.388e-0 |  0.4514   | -0.01771  | -0.005214 |
# [[9.6069707e-05 1.0246708e-04 4.6236400e-04 5.6610997e-07 5.8569788e-07]]
# |  43       | -5.758e-0 |  0.4778   |  0.001214 |  0.000287 |
# [[9.4249284e-05 9.9645717e-05 4.6247794e-04 5.6587169e-07 5.8524103e-07]]
# |  44       | -5.755e-0 |  0.4779   | -8.852e-0 |  0.00019  |
# [[1.0209628e-04 1.0404437e-04 4.6276132e-04 5.6891406e-07 5.8517156e-07]]
# |  45       | -5.77e-07 |  0.478    |  0.002468 | -0.002003 |
# [[8.3203122e-05 1.1422279e-04 4.6174761e-04 5.6937660e-07 5.8364219e-07]]
# |  46       | -5.765e-0 |  0.4768   | -0.001707 |  0.000947 |
# [[8.7917258e-05 1.1224074e-04 4.6206906e-04 5.6641790e-07 5.8483255e-07]]
# |  47       | -5.756e-0 |  0.477    | -0.000469 | -0.000827 |
# [[8.9432928e-05 1.1857067e-04 4.6190730e-04 5.6536908e-07 5.8538603e-07]]
# |  48       | -5.753e-0 |  0.4767   |  0.000899 | -0.001209 |
# [[1.0087030e-04 1.1830217e-04 4.6215599e-04 5.6978854e-07 5.9214130e-07]]
# |  49       | -5.809e-0 |  0.4773   |  0.004947 | -0.001471 |
# [[2.0505874e-04 3.6538133e-04 4.5997265e-04 6.7651195e-07 9.7164889e-07]]
# |  50       | -8.108e-0 |  0.468    |  0.01382  | -0.01477  |
# =============================================================

# %%
SOL_opt = optimizer.max['params']['varx']
CQ_opt = optimizer.max['params']['vary']
SQ_opt = optimizer.max['params']['varz']
print('optimum (pv_units) ',SOL_opt, CQ_opt, SQ_opt)

opt_emit = -1*optimizer.max['target']
print('optimum geom emit ', opt_emit)
# Out:
# optimum (pv_units)  0.4774165407092916 7.604107942579472e-05 0.00047270647613400704
# optimum geom emit  5.74912007778039e-07
